# %%
import numpy as np
import pandas as pd

# %%
data=np.genfromtxt('C:\\Users\\GB\\\Desktop\\coding ninja\\multivaraiable gradient 2\\project1\\training_boston_x_y_train.csv',delimiter=',')
data_test=np.genfromtxt('C:\\Users\\GB\\Desktop\\coding ninja\\multivaraiable gradient 2\\project1\\test_boston_x_test.csv',delimiter=',')

x=data[:,0:13]
y=data[:,13]
data_test.shape
# Out:
# (127, 13)

# %%
x[:,0].shape
# Out:
# (379,)

# %%
df=pd.DataFrame(x)
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1 -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2  0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3  0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4 -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
#
#          7         8         9         10        11        12
# 0 -0.520264 -0.752922 -1.278354 -0.303094  0.410571 -1.097990
# 1  0.336351 -0.523001 -0.060801  0.113032  0.291169 -0.520474
# 2 -0.577309  1.661245  1.530926  0.806576 -3.795795  0.891076
# 3 -0.712836  1.661245  1.530926  0.806576 -0.066050  0.215438
# 4  0.300508 -0.752922 -0.957633  0.020560  0.431074  0.029007

# %%
x[2,4]
# Out:
# 1.36749033

# %%
dff=pd.DataFrame(data_test)
dff.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.918166 -0.487722  1.015999 -0.272599  0.365444 -1.609343  1.117494
# 1 -0.403392 -0.487722  0.406098 -0.272599 -1.016689  0.560412 -1.332629
# 2 -0.413178 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 3 -0.412649  0.413589 -0.802031 -0.272599 -0.999412 -0.408356 -1.677566
# 4 -0.405882 -0.487722 -0.375976 -0.272599 -0.299707 -0.127698 -0.504068
#
#          7         8         9         10        11        12
# 0 -1.048494  1.661245  1.530926  0.806576 -1.597551  1.041062
# 1  1.029344 -0.637962 -0.708183 -1.135347  0.441052 -0.894738
# 2 -0.716639 -0.982843 -0.803212  1.176466  0.441052 -0.500850
# 3  1.435452 -0.637962 -0.981390 -0.765457  0.441052 -0.591963
# 4 -0.483566 -0.523001 -0.143951  1.130230  0.403663  0.048631

# %%
array=['a','b','c','d','e','f','g','h','i','k','l','m','n']

# %%
for i in range(13):
    for j in range(13):
        if i!=j:
                df[array[i]+array[j]]=df[i]*df[j]
                dff[array[i]+array[j]]=dff[i]*dff[j]
dff.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  2.918166 -0.487722  1.015999 -0.272599  0.365444 -1.609343  1.117494
# 1 -0.403392 -0.487722  0.406098 -0.272599 -1.016689  0.560412 -1.332629
# 2 -0.413178 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 3 -0.412649  0.413589 -0.802031 -0.272599 -0.999412 -0.408356 -1.677566
# 4 -0.405882 -0.487722 -0.375976 -0.272599 -0.299707 -0.127698 -0.504068
#
#           7         8         9    ...           nc        nd        ne  \
# 0 -1.048494  1.661245  1.530926    ...     1.057718 -0.283792  0.380450
# 1  1.029344 -0.637962 -0.708183    ...    -0.363351  0.243904  0.909670
# 2 -0.716639 -0.982843 -0.803212    ...    -0.057968  0.136531 -0.079196
# 3  1.435452 -0.637962 -0.981390    ...     0.474773  0.161368  0.591615
# 4 -0.483566 -0.523001 -0.143951    ...    -0.018284 -0.013257 -0.014575
#
#          nf        ng        nh        ni        nk        nl        nm
# ...

# %%
x=df.values
x.shape
# Out:
# (379, 169)

# %%
data_test=dff.values
data_test.shape
# Out:
# (127, 169)

# %%
from sklearn import preprocessing
sc=preprocessing.StandardScaler()
x=sc.fit(x).transform(x)
data_test=sc.transform(data_test)

# %%
a=np.ones((len(data_test)),int).reshape(-1,1)
data_test=np.append(data_test,a,axis=1)
data_test.shape
# Out:
# (127, 170)

# %%
a=np.ones((len(data)),int).reshape(-1,1)
x=np.append(x,a,axis=1)
x.shape
# Out:
# (379, 170)

# %%
def cost(x,y,m,points):
    M=len(points)
    total_cost=0
    s=0
    for i in range(M):
            s=np.dot(m,x[i])
            total_cost +=(1/M)*((y[i]-s )**2)
            s=0
       
                        
    return total_cost

# %%
def step_gradient(points,learning_rate,m):
    m_slope=np.zeros(170)
    new_m=np.zeros(170)
    M=len(points)
    for i in range(M):
                  m_slope += np.dot(x[i], (y[i]-np.dot(m,x[i])))*(-2/M)
                      
    for j in range(170):    
         new_m[j]=m[j]-learning_rate*m_slope[j]
    return new_m

# %%
def gd(points,learning_rate,num_iteration):
    m=np.zeros(170)
    for i in range(num_iteration):
        m=step_gradient(points,learning_rate,m)
        print(i ,'cost:',cost(x,y,m,points) )
        
    return m

# %%
def run():
    num_iteration=400
    
    learning_rate=0.02
    y_pred=np.zeros(len(data_test))
    m=gd(data,learning_rate,num_iteration)
    y_pred=predict(m,data_test,y_pred)
    np.savetxt('C:\\Users\\guru1_000\\Desktop\\ml\\multivariable and gradient regression 2\\y_pred_project12',y_pred,delimiter=",",fmt='%.5f')
    print(m)
    print(y_pred.shape)
    print(y_pred)

# %%
def predict(m,data_test,y_pred):
    
    for i in range(len(data_test)):
            y_pred[i]=np.dot(m,data_test[i])
    return y_pred

# %%
run()
# Out:
# 0 cost: 526.2245381569676
# 1 cost: 476.17343984830075
# 2 cost: 435.0900523306889
# 3 cost: 399.3804089735003
# 4 cost: 367.52448206522877
# 5 cost: 338.73121282671326
# 6 cost: 312.5215163778126
# 7 cost: 288.5665315308067
# 8 cost: 266.61792930454766
# 9 cost: 246.47532192217034
# 10 cost: 227.96980000721075
# 11 cost: 210.95494868058785
# 12 cost: 195.30154741622397
# 13 cost: 180.8941961982809
# 14 cost: 167.62901222256963
# 15 cost: 155.4119592371731
# 16 cost: 144.15757379469903
# 17 cost: 133.78795480581454
# 18 cost: 124.23193669464388
# 19 cost: 115.42439624492062
# 20 cost: 107.30566045570166
# 21 cost: 99.82099314087392
# 22 cost: 92.92014456473589
# 23 cost: 86.55695268807817
# 24 cost: 80.68898748544697
# 25 cost: 75.2772317940719
# 26 cost: 70.28579357451864
# 27 cost: 65.68164549296891
# 28 cost: 61.43438849723802
# 29 cost: 57.51603663346514
# 30 cost: 53.90082079179386
# 31 cost: 50.565009414153536
# 32 cost: 47.486744471103336
# 33 cost: 44.645891235655256
# ...
